# %% [markdown]
# # Homework_20210118
#
# > ## 강의 노트 요약 및 배울 것 정리

# %%
from IPython.display import Image

Image("c:/Users/JCdata/Downloads/0118191817225765 (2).jpg")

# %% [markdown]
# ### 1. 새로 배운 점
# > #### Exe 파일은 win에서 실행가능하다.
# > #### Console, terminal, shell에 대한 개념 정리
# > #### Jupyter notebook의 단축키
# >> ##### ctrl + shift + - : 위 아래 나누기
# >> ##### shift + m : 아래 셀과 합치기
# >> ##### dd : 셀 삭제
# >> ##### b : 아래로 셀 추가

# %% [markdown]
# ### 2. 새로 공부 할 것
# > #### 2.1 Vim 에디터의 단축키
# ![키](https://gmlwjd9405.github.io/images/etc/vim-shortkey-keyboard.png)

# %% [markdown]
# > #### 2.2 Linux, windows의 터미널 단축키
#
# | 명령 | Windows | Linux |
# |:---------|:----------|:--------|
# |파일복사|copy     | cp    |
# |파일이동|move     |mv     |
# |파일 목록보기|dir|ls|
# |파일 삭제|del,erase|rm|
# |이름 변경|move|mv|
# |디렉토리 이동|cd|cd|
# |현재 디렉토리|cd|pwd|
# |화면 정리|cls|clear|
# |파일 내용 표시|type|cat|
# |도움말|help|man|
# |종료|exit|exit|
# |시간표시|time|date|
# |버전 정보|ver|uname -a|
# |파일 문자열 찾기|find|find|
# |압축|pkzip|tar, zip|
# |프로세스 정보|taskmgr|ps, top|
# |프로세스 종료|tskill|kill, killall|

# %% [markdown]
# > #### 2.3 Markdown 명령어
#
# >> ##### '#' 부호로 타이틀 문자 크기 조절
# >> ##### '>' 부호로 들여쓰기
# >> ##### |, :-- 를 이용하여 table 만들기
# >> ##### 인터넷에서 이미지 파일 주소로 가져오기

# %% [markdown]
# ### 3. 인용
#     https://eungbean.github.io/2018/06/11/How-to-use-markdown/: 마크다운 사용법
#     https://gmlwjd9405.github.io/2019/05/14/vim-shortkey.html: vim 단축키
#     https://kkokkilkon.tistory.com/151 : jupyter nootbook 단축키

# %% [markdown]
# ### 4. 감사한 것
# 1. 마크다운에 대한 언급을 한 조원 김상현씨에게 감사합니다
# 2. 오늘 첫날인데 불구하고 팀원간 소통할 수 있도록 리더의 역할을 한 이주남씨에게 감사합니다
# 3. 열심히 의견 수립하려한 팔색조 팀원들 감사합니다.
